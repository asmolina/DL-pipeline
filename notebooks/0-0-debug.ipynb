# %%
from PIL import Image

for item in one_date.train_dataloader():
    print(item[0].shape) # img
    print(item[1].shape) # label
    print(item[2].shape) # scl_mask
    print(len(item))
    plt.imshow(item[1][1, :, :])
    plt.show()
    plt.imshow(Image.fromarray(item[1][1, :, :].numpy()))
    plt.show()
    break
# Out:
# 🤖: #iterations in train dataloader: 3
# torch.Size([64, 10, 256, 256])
# torch.Size([64, 256, 256])
# torch.Size([64, 1, 256, 256])
# 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/geotorch/lib/python3.10/site-packages/PIL/Image.py:3080, in fromarray(obj, mode)
#    3079 try:
# -> 3080     mode, rawmode = _fromarray_typemap[typekey]
#    3081 except KeyError as e:
#
# KeyError: ((1, 1), '<i8')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 10
#       8 plt.imshow(item[1][1, :, :])
#       9 plt.show()
# ---> 10 plt.imshow(Image.fromarray(item[1][1, :, :].numpy()))
#      11 plt.show()
#      12 break
#
# File ~/.conda/envs/geotorch/lib/python3.10/site-packages/PIL/Image.py:3083, in fromarray(obj, mode)
# ...
